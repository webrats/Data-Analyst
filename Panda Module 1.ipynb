# %%
import pandas as pd

# %%
df = pd.read_csv("C://Users//amitn//Desktop//work//Machine Learning//csv//weather.csv")

# %%
df
# Out:
#             PDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0      9/1/2015                75                 67                58
# 1      9/2/2015                73                 68                62
# 2      9/3/2015                70                 65                60
# 3      9/4/2015                72                 64                55
# 4      9/5/2015                79                 65                51
# ...         ...               ...                ...               ...
# 1825  8/27/2016                78                 70                61
# 1826  8/28/2016                79                 70                60
# 1827  8/29/2016                76                 68                60
# 1828  8/30/2016                81                 70                59
# 1829  8/31/2016                78                 69                60
#
#       Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# ...

# %%
df.columns
# Out:
# Index(['PDT', 'Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF',
#        'Max Dew PointF', 'MeanDew PointF', 'Min DewpointF', 'Max Humidity',
#        ' Mean Humidity', ' Min Humidity', ' Max Sea Level PressureIn',
#        ' Mean Sea Level PressureIn', ' Min Sea Level PressureIn',
#        ' Max VisibilityMiles', ' Mean VisibilityMiles', ' Min VisibilityMiles',
#        ' Max Wind SpeedMPH', ' Mean Wind SpeedMPH', ' Max Gust SpeedMPH',
#        'PrecipitationIn', ' CloudCover', ' Events', ' WindDirDegrees', 'ZIP'],
#       dtype='object')

# %%
df = df[['PDT', 'Max TemperatureF', 'Min TemperatureF', 'Max Humidity',
        ' Min Humidity',' Max Wind SpeedMPH', ' CloudCover', ' Events', 'ZIP']]
df
# Out:
#             PDT  Max TemperatureF  Min TemperatureF  Max Humidity  \
# 0      9/1/2015                75                58            84
# 1      9/2/2015                73                62            78
# 2      9/3/2015                70                60            84
# 3      9/4/2015                72                55            77
# 4      9/5/2015                79                51            89
# ...         ...               ...               ...           ...
# 1825  8/27/2016                78                61            72
# 1826  8/28/2016                79                60            84
# 1827  8/29/2016                76                60            78
# 1828  8/30/2016                81                59            78
# 1829  8/31/2016                78                60            84
#
#        Min Humidity   Max Wind SpeedMPH   CloudCover  Events    ZIP
# 0                49                  22            2     NaN  94107
# ...

# %%
df.shape
# Out:
# (1830, 9)

# %%
row , column = df.shape
row
# Out:
# 1830

# %%
column
# Out:
# 9

# %% [markdown]
# # Row View

# %%
df.head()
# Out:
#         PDT  Max TemperatureF  Min TemperatureF  Max Humidity   Min Humidity  \
# 0  9/1/2015                75                58            84             49
# 1  9/2/2015                73                62            78             57
# 2  9/3/2015                70                60            84             53
# 3  9/4/2015                72                55            77             44
# 4  9/5/2015                79                51            89             30
#
#     Max Wind SpeedMPH   CloudCover  Events    ZIP
# 0                  22            2     NaN  94107
# 1                  23            5     NaN  94107
# 2                  18            2     NaN  94107
# 3                  20            2     NaN  94107
# 4                  21            2     NaN  94107

# %%
df.head(3)
# Out:
#         PDT  Max TemperatureF  Min TemperatureF  Max Humidity   Min Humidity  \
# 0  9/1/2015                75                58            84             49
# 1  9/2/2015                73                62            78             57
# 2  9/3/2015                70                60            84             53
#
#     Max Wind SpeedMPH   CloudCover  Events    ZIP
# 0                  22            2     NaN  94107
# 1                  23            5     NaN  94107
# 2                  18            2     NaN  94107

# %%
df.tail()
# Out:
#             PDT  Max TemperatureF  Min TemperatureF  Max Humidity  \
# 1825  8/27/2016                78                61            72
# 1826  8/28/2016                79                60            84
# 1827  8/29/2016                76                60            78
# 1828  8/30/2016                81                59            78
# 1829  8/31/2016                78                60            84
#
#        Min Humidity   Max Wind SpeedMPH   CloudCover  Events    ZIP
# 1825             46                  17            4     NaN  95113
# 1826             45                  17            4     NaN  95113
# 1827             49                  21            6     NaN  95113
# 1828             42                  18            2     NaN  95113
# 1829             43                  20            1     NaN  95113

# %%
df.tail(10)
# Out:
#             PDT  Max TemperatureF  Min TemperatureF  Max Humidity  \
# 1820  8/22/2016                77                60            84
# 1821  8/23/2016                81                60            84
# 1822  8/24/2016                78                60            84
# 1823  8/25/2016                76                60            84
# 1824  8/26/2016                81                60            84
# 1825  8/27/2016                78                61            72
# 1826  8/28/2016                79                60            84
# 1827  8/29/2016                76                60            78
# 1828  8/30/2016                81                59            78
# 1829  8/31/2016                78                60            84
#
#        Min Humidity   Max Wind SpeedMPH   CloudCover  Events    ZIP
# 1820             46                  18            3     NaN  95113
# 1821             42                  16            4     NaN  95113
# ...

# %%
df[2:5]
# Out:
#         PDT  Max TemperatureF  Min TemperatureF  Max Humidity   Min Humidity  \
# 2  9/3/2015                70                60            84             53
# 3  9/4/2015                72                55            77             44
# 4  9/5/2015                79                51            89             30
#
#     Max Wind SpeedMPH   CloudCover  Events    ZIP
# 2                  18            2     NaN  94107
# 3                  20            2     NaN  94107
# 4                  21            2     NaN  94107

# %%
df[:]
# Out:
#             PDT  Max TemperatureF  Min TemperatureF  Max Humidity  \
# 0      9/1/2015                75                58            84
# 1      9/2/2015                73                62            78
# 2      9/3/2015                70                60            84
# 3      9/4/2015                72                55            77
# 4      9/5/2015                79                51            89
# ...         ...               ...               ...           ...
# 1825  8/27/2016                78                61            72
# 1826  8/28/2016                79                60            84
# 1827  8/29/2016                76                60            78
# 1828  8/30/2016                81                59            78
# 1829  8/31/2016                78                60            84
#
#        Min Humidity   Max Wind SpeedMPH   CloudCover  Events    ZIP
# 0                49                  22            2     NaN  94107
# ...

# %% [markdown]
# # Columns Vews

# %%
df.columns
# Out:
# Index(['PDT', 'Max TemperatureF', 'Min TemperatureF', 'Max Humidity',
#        ' Min Humidity', ' Max Wind SpeedMPH', ' CloudCover', ' Events', 'ZIP'],
#       dtype='object')

# %%
df.ZIP # df['ZIP']
# Out:
# 0       94107
# 1       94107
# 2       94107
# 3       94107
# 4       94107
#         ...
# 1825    95113
# 1826    95113
# 1827    95113
# 1828    95113
# 1829    95113
# Name: ZIP, Length: 1830, dtype: int64

# %%
df['Max TemperatureF']
# Out:
# 0       75
# 1       73
# 2       70
# 3       72
# 4       79
#         ..
# 1825    78
# 1826    79
# 1827    76
# 1828    81
# 1829    78
# Name: Max TemperatureF, Length: 1830, dtype: int64

# %%
df[['Max TemperatureF' , 'PDT']]
#return Only 2 columns
# Out:
#       Max TemperatureF        PDT
# 0                   75   9/1/2015
# 1                   73   9/2/2015
# 2                   70   9/3/2015
# 3                   72   9/4/2015
# 4                   79   9/5/2015
# ...                ...        ...
# 1825                78  8/27/2016
# 1826                79  8/28/2016
# 1827                76  8/29/2016
# 1828                81  8/30/2016
# 1829                78  8/31/2016
#
# [1830 rows x 2 columns]

# %% [markdown]
# # Numaric Function for columns

# %%
df.columns
# Out:
# Index(['PDT', 'Max TemperatureF', 'Min TemperatureF', 'Max Humidity',
#        ' Min Humidity', ' Max Wind SpeedMPH', ' CloudCover', ' Events', 'ZIP'],
#       dtype='object')

# %%
df['Max TemperatureF'].max()
# Out:
# 134

# %%
df['Max TemperatureF'].mean()
# Out:
# 70.1431693989071

# %%
df['Max TemperatureF'].describe()
#statics for numaric columns
# Out:
# count    1830.000000
# mean       70.143169
# std         9.593330
# min        46.000000
# 25%        63.000000
# 50%        70.000000
# 75%        77.000000
# max       134.000000
# Name: Max TemperatureF, dtype: float64

# %%
df.describe()
#statics for numaric columns
# Out:
#        Max TemperatureF  Min TemperatureF  Max Humidity   Min Humidity  \
# count       1830.000000       1830.000000   1830.000000    1830.000000
# mean          70.143169         51.965574     86.536066      48.457377
# std            9.593330          6.974563      8.479129      14.077816
# min           46.000000          1.000000     46.000000       6.000000
# 25%           63.000000         48.000000     82.000000      40.000000
# 50%           70.000000         53.000000     87.000000      49.000000
# 75%           77.000000         57.000000     93.000000      57.000000
# max          134.000000         69.000000    100.000000      93.000000
#
#         Max Wind SpeedMPH   CloudCover           ZIP
# count         1830.000000  1830.000000   1830.000000
# mean            16.490710     3.084699  94325.000000
# std              6.137184     2.369603    404.670589
# min              0.000000     0.000000  94041.000000
# 25%             13.000000     1.000000  94063.000000
# ...

# %% [markdown]
# # Condition base row access

# %%
df[df['Max TemperatureF'] >=90].head()
# Out:
#           PDT  Max TemperatureF  Min TemperatureF  Max Humidity  \
# 6    9/7/2015                91                54            67
# 7    9/8/2015                95                57            67
# 8    9/9/2015                93                60            73
# 19  9/20/2015                91                56            72
# 20  9/21/2015                91                61            78
#
#      Min Humidity   Max Wind SpeedMPH   CloudCover  Events    ZIP
# 6              16                  13            1     NaN  94107
# 7              19                  14            0     NaN  94107
# 8              21                  16            0     NaN  94107
# 19             23                  14            1     NaN  94107
# 20             25                  20            0     NaN  94107

# %%
df[df['Max TemperatureF'] == df['Max TemperatureF'].max()]
# Out:
#             PDT  Max TemperatureF  Min TemperatureF  Max Humidity  \
# 443  11/17/2015               134                48            87
#
#       Min Humidity   Max Wind SpeedMPH   CloudCover  Events    ZIP
# 443              7                  14            2     NaN  94063

# %%
df[['PDT','Max TemperatureF']][df['Max TemperatureF'] == df['Max TemperatureF'].max()]
#Specific column
# Out:
#             PDT  Max TemperatureF
# 443  11/17/2015               134

# %% [markdown]
# # indexing

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1830, step=1)

# %%
df
# Out:
#            Max TemperatureF  Min TemperatureF  Max Humidity   Min Humidity  \
# PDT
# 9/1/2015                 75                58            84             49
# 9/2/2015                 73                62            78             57
# 9/3/2015                 70                60            84             53
# 9/4/2015                 72                55            77             44
# 9/5/2015                 79                51            89             30
# ...                     ...               ...           ...            ...
# 8/27/2016                78                61            72             46
# 8/28/2016                79                60            84             45
# 8/29/2016                76                60            78             49
# 8/30/2016                81                59            78             42
# 8/31/2016                78                60            84             43
#
#             Max Wind SpeedMPH   CloudCover  Events    ZIP
# ...

# %%
df.set_index("PDT",inplace=True)
#change index

# %%
df
# Out:
#            index  Max TemperatureF  Min TemperatureF  Max Humidity  \
# PDT
# 9/1/2015       0                75                58            84
# 9/2/2015       1                73                62            78
# 9/3/2015       2                70                60            84
# 9/4/2015       3                72                55            77
# 9/5/2015       4                79                51            89
# ...          ...               ...               ...           ...
# 8/27/2016   1825                78                61            72
# 8/28/2016   1826                79                60            84
# 8/29/2016   1827                76                60            78
# 8/30/2016   1828                81                59            78
# 8/31/2016   1829                78                60            84
#
#             Min Humidity   Max Wind SpeedMPH   CloudCover  Events    ZIP
# PDT
# 9/1/2015              49                  22            2     NaN  94107
# ...

# %%
df.loc['8/29/2016']
# Out:
#            index  Max TemperatureF  Min TemperatureF  Max Humidity  \
# PDT
# 8/29/2016    363                73                59            84
# 8/29/2016    729                73                57            82
# 8/29/2016   1095                73                59            82
# 8/29/2016   1461                73                59            84
# 8/29/2016   1827                76                60            78
#
#             Min Humidity   Max Wind SpeedMPH   CloudCover  Events    ZIP
# PDT
# 8/29/2016             61                  20            5     NaN  94107
# 8/29/2016             50                  16            5     NaN  94063
# 8/29/2016             50                  21            4     NaN  94301
# 8/29/2016             53                  18            4     NaN  94041
# 8/29/2016             49                  21            6     NaN  95113

# %%
df.reset_index(inplace=True)
df
# Out:
#       index        PDT  Max TemperatureF  Min TemperatureF  Max Humidity  \
# 0         0   9/1/2015                75                58            84
# 1         1   9/2/2015                73                62            78
# 2         2   9/3/2015                70                60            84
# 3         3   9/4/2015                72                55            77
# 4         4   9/5/2015                79                51            89
# ...     ...        ...               ...               ...           ...
# 1825   1825  8/27/2016                78                61            72
# 1826   1826  8/28/2016                79                60            84
# 1827   1827  8/29/2016                76                60            78
# 1828   1828  8/30/2016                81                59            78
# 1829   1829  8/31/2016                78                60            84
#
#        Min Humidity   Max Wind SpeedMPH   CloudCover  Events    ZIP
# ...

# %%
df[' Events'].fillna(0)
# Out:
# PDT
# 9/1/2015     0
# 9/2/2015     0
# 9/3/2015     0
# 9/4/2015     0
# 9/5/2015     0
#             ..
# 8/27/2016    0
# 8/28/2016    0
# 8/29/2016    0
# 8/30/2016    0
# 8/31/2016    0
# Name:  Events, Length: 1830, dtype: object
